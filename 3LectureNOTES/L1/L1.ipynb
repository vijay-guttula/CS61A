# %%
#2 + (4 * 8 * 3 * 2)
from operator import add, mul
print(add(2, mul(mul(4,8),mul(3,2))))
# Out:
# 194

# %%
shakes = open('note.txt')
text = shakes.read().split()
print(len(text))
# Out:
# 980637

# %%
text.count('the')
# Out:
# 23272

# %%
text.count('thou')
# Out:
# 4501

# %%
words = set(text)
print(words)
# Out:
# {'tardied', "alter'd", 'unkindly', 'manifest', 'devoutly', 'protectors', 'Beating', "Re-quicken'd", 'Finger', 'traducement', 'Affrighted', 'Charming', 'Park', 'Seleucus', 'demise', 'giant-like', 'she-angel', "trill'd", 'Loves', 'disputes', 'Cudgel', 'pit-fall', 'Boldly', ',well', 'hunt', 'remorseless', ',as', "sland'rous", '!Come', 'Strip', "'Sweep", 'buttocks', 'idolatry', 'presented', 'flood-gate', 'council-board', "Bewray'd", 'gnawing', 'anticipation', 'default', 'ill-divining', 'impart', 'Blaspheming', 'smoking', 'Nose', 'suppress', 'Capulet', 'hereabouts', 'flows', 'precor', "unpolish'd", 'ox-head', "continu'd", 'ingratitudes', 'Guiltier', 'Falstaff', "thrall'd", 'ale-wife', 'hushes', "meal'd", 'ditches', 'maces', 'just', "He'd", 'distressed', 'outwork', 'cases', 'bringings', "halter'd", 'Tapers', 'Abhorred', "fir'd", 'woodland', 'Lords', 'sun-rising', 'Beauteous', 'Recking', 'Blows', 'remnants', 'bribe', 'dowager', 'redresses', 'Landlord', 'detected', 'sweating', 'Foolhardiness
# ...

# %%
'forsooth' in words
# Out:
# True

# %%
'draw'
# Out:
# 'draw'

# %%
'draw'[::-1]
# Out:
# 'ward'

# %%
#lets try to find palindrome words
{w for w in words if w == w[::-1] and len(w) > 2}
# Out:
# {"'I'",
#  'III',
#  'bob',
#  'dad',
#  'deed',
#  'did',
#  'ecce',
#  'eke',
#  'elle',
#  'ere',
#  'esse',
#  'eve',
#  'ewe',
#  'eye',
#  'gig',
#  'level',
#  'madam',
#  'minim',
#  'mum',
#  'non',
#  'noon',
#  'nun',
#  'pap',
#  'peep',
#  'pip',
#  'poop',
#  'redder',
#  'refer',
#  'rever',
#  'sees',
#  'tut',
#  'viv',
#  'wow'}
